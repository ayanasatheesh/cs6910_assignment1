# %%
# !python /kaggle/input/ayanan/train.py --optimizer adam --epochs 5 --learning_rate 0.001 --batch_size 32 --loss squared_error --activation tanh --num_layers 5 --hidden_size 32 --weight_init xavier
# Out:
# wandb: Currently logged in as: cs22m025. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# ...
# 4422102/4422102 [==============================] - 0s 0us/step
# wandb: wandb version 0.13.11 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20230312_190601-mou2czhg
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run iconic-thunder-452
# wandb: ⭐️ View project at https://wandb.ai/cs22m025/assignment1
# wandb: 🚀 View run at https://wandb.ai/cs22m025/assignment1/runs/mou2czhg
# ___________________________________________________________________
# Running Adam.....
# epoch: 1 loss: 0.5809147121779843 0.5910253524153617
# epoch: 2 loss: 0.5230797265506246 0.5315270351232648
# epoch: 3 loss: 0.49756387267997215 0.5010591476130467
# ...

# %% [markdown]
# !python /kaggle/input/xyzwuv/train.py --optimizer adam --epochs 5 --l_rate 0.001 --batch_size 32 --loss squared_error --activation tanh --n_hlayers 5 --hlayer_size 32 --initializer xavier

# %% [markdown]
# !python /kaggle/input/xyzwuv/train.py --optimizer adam --epochs 5 --l_rate 0.001 --batch_size 32 --loss squared_error --activation tanh --n_hlayers 5 --hlayer_size 32 --initializer xavier

# %%
Loss=[0,0,0,0]
epoch=[1,2,3,4]
# !python /kaggle/input/training/original.py plotloss(Loss,epoch)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `python /kaggle/input/training/original.py plotloss(Loss,epoch)'

# %%
import original
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_28/554201614.py in <module>
# ----> 1 import original
#
# ModuleNotFoundError: No module named 'original'
