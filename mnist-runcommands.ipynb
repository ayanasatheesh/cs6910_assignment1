# %%
# !python /kaggle/input/assignment1dll/train.py --dataset mnist
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# ...
# 11490434/11490434 [==============================] - 0s 0us/step
# wandb: Currently logged in as: cs22m025. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.14.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20230318_190213-55jiyrpv
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cs22m025
# wandb: ⭐️ View project at https://wandb.ai/cs22m025/assignment1
# wandb: 🚀 View run at https://wandb.ai/cs22m025/assignment1/runs/55jiyrpv
# ___________________________________________________________________
# Running Adam.....
# epoch: 1 loss: 0.1498857736388052 0.15589569939072861
# epoch: 2 loss: 0.1052865335528477 0.12015559480624884
# ...

# %%
# !python /kaggle/input/assignment1dll/train.py --dataset mnist --optimizer nadam --epochs 5 --learning_rate 0.001 --batch_size 16 --loss cross_entropy --hidden_size 128 --num_layers 4 --weight_init xavier --weight_decay 0.0005
# Out:
# wandb: Currently logged in as: cs22m025. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: wandb version 0.14.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20230318_193952-zf8j4dsa
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cs22m025
# wandb: ⭐️ View project at https://wandb.ai/cs22m025/assignment1
# wandb: 🚀 View run at https://wandb.ai/cs22m025/assignment1/runs/zf8j4dsa
# ___________________________________________________________________
# Running Nadam.....
# epoch: 1 loss: 0.15659454891079003 0.16063175141477132
# epoch: 2 loss: 0.1085635266092645 0.12360876797824602
# epoch: 3 loss: 0.0807038567303116 0.1039339331783333
# epoch: 4 loss: 0.06203480254422491 0.09161050519127395
# ...

# %%
# !python /kaggle/input/assignment1dll/train.py --dataset mnist --optimizer adam --epochs 20 --learning_rate 0.001 --batch_size 16 --loss cross_entropy --hidden_size 64 --num_layers 3 --weight_init xavier --weight_decay 0.0005
# Out:
# wandb: Currently logged in as: cs22m025. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: wandb version 0.14.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.10
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20230318_194732-9mluk2jc
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cs22m025
# wandb: ⭐️ View project at https://wandb.ai/cs22m025/assignment1
# wandb: 🚀 View run at https://wandb.ai/cs22m025/assignment1/runs/9mluk2jc
# ___________________________________________________________________
# Running Adam.....
# epoch: 1 loss: 0.18912273543936842 0.19548142921754777
# epoch: 2 loss: 0.14201678277088745 0.15368379566711962
# epoch: 3 loss: 0.11640565778408166 0.1322363733653044
# epoch: 4 loss: 0.10012556779711936 0.11957307048306981
# ...
